# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import urllib.parse

# %%
base_url = "https://codigo-postal.co/argentina/cordoba/"
response = requests.get(base_url)

# %%
# Verificar el estado de la respuesta
if response.status_code == 200:
    # Parsear el contenido HTML con BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Encontrar la tabla que contiene las localidades de Córdoba
    table = soup.find("ul", class_="cities")

    # Encontrar todos los elementos <a> dentro del elemento <ul>
    a_elements = table.find_all("a")
    
    #  Obtener el texto de cada elemento <a>
    localidades = [a.text for a in a_elements]
    
    # Crear un DataFrame con las localidades
    df_localidades = pd.DataFrame({"Localidad": localidades})
    
    # Guardar el DataFrame en un archivo CSV
    df_localidades.to_csv("localidades_cordoba.csv", index=False)
    
    print("Archivo CSV guardado exitosamente.")
else:
    print("Error al acceder a la página de Córdoba")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 10
#       7 table = soup.find("ul", class_="cities")
#       9 # Encontrar todos los elementos <a> dentro del elemento <ul>
# ---> 10 a_elements = table.find_all("a")
#      12 #  Obtener el texto de cada elemento <a>
#      13 localidades = [a.text for a in a_elements]
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# Crear una nueva sesión con un límite máximo de redirecciones
s = requests.Session()
s.max_redirects = 10

df_localidades = pd.read_csv("localidades_cordoba.csv")

# Reemplazar espacios por guiones y convertir a minúsculas en cada localidad
df_localidades["Localidad"] = df_localidades["Localidad"].str.replace(" ", "-").replace("Ã±", "a").str.lower()


# Crear una lista para almacenar los datos de los CPAs
data = []

for localidad in df_localidades["Localidad"]:
    localidad_codificada = urllib.parse.quote(localidad)
    url_localidad = f"{base_url}/{localidad_codificada}"

    try:
        # Realizar solicitud GET sin redireccionamiento automático
        response = s.get(url_localidad, allow_redirects=True)
    
        response.raise_for_status()  # Esta línea lanzará una excepción si la solicitud falla

        soup = BeautifulSoup(response.content, "html.parser")
        
        # Obtener los textos de los elementos <a>
        a_texts = []
        tbody = soup.find("tbody")
        
        if tbody:
            rows = tbody.find_all("tr")
            first_a = True
            
            for row in rows:
                cells = row.find_all("td")

                
                for cell in cells:
                    a_elements = cell.find_all("a")
                    
                    # Añadir una variable de control para imprimir solo el primer 'a' de cada fila
                    
                    
                    for a in a_elements:
                        
                        if first_a:
                            print(a.text)
                            first_a = False

                            a_texts.append(a.text)
        
        # Agregar los datos a la lista
        data.append({"Localidad": localidad, "CPAs": a_texts})
       
    except requests.exceptions.RequestException as e:
        print(f"Error al acceder a la página de {localidad}: {e}")

# Crear un DataFrame a partir de los datos recolectados
df_resultado = pd.DataFrame(data)

# Guardar el DataFrame en un archivo CSV
df_resultado.to_csv("cordoba_cpa.csv", index=False)
print("Archivo CSV guardado exitosamente.")
# Out:
# X5272XAB
# X5220XAT
# X5216XAE
# X5871XAD
# X5285XAD
# X5221XAT
# X5155XAL
# X5216XAE
# X5212XAO
# X5209XAY
# X5209XAY
# X5284XBB
# X5221XAT
# Buscar CPA
# Buscar CPA
# X5885XAB
# X5221XAT
# Buscar CPA
# Buscar CPA
# X5801XAJ
# Buscar CPA
# Buscar CPA
# X5871XAD
# X5182XAD
# X5145XAK
# X5119XAG
# X5203XAB
# X5875XAC
# X5281XAY
# X5174XAB
# X5119XAG
# X5295XAA
# X5893XAC
# X5885XAB
# X5205XAA
# Buscar CPA
# X5199XAK
# X5299XAN
# X5155XAL
# X5248XAB
# Buscar CPA
# X6271XAC
# X5216XAE
# X2432XAE
# X5873XAC
# X5297XAO
# X2341XAA
# Buscar CPA
# X5297XAO
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5901XAD
# X5889XAG
# X5889XAG
# X5859XAG
# X5825XAA
# X5819XAG
# X5196XAE
# X5819XAG
# X5825XAA
# X5117XAA
# X2671XAC
# X5225XAB
# X5194XAD
# X5196XAE
# X5145XAK
# X5901XAD
# X5212XAO
# Error al acceder a la página de ã‘u-pora: Exceeded 10 redirects.
# Error al acceder a la página de baã±ado-de-paja: Exceeded 10 redirects.
# Error al acceder a la página de baã±ado-de-soto: Exceeded 10 redirects.
# Error al acceder a la página de baã±ado-del-fuerte: Exceeded 10 redirects.
# Buscar CPA
# Buscar CPA
# X5101XAB
# X5101XAB
# X5961XAB
# X5221XAT
# Buscar CPA
# Buscar CPA
# X5887XAA
# X5961XAB
# X5101XAB
# X5231XAA
# X5270XAI
# X5248XAB
# X5871XAD
# X5871XAD
# X5871XAD
# Buscar CPA
# Buscar CPA
# X5137XAV
# X5875XAC
# X5212XAO
# X5281XAY
# X5284XBB
# X2550XAB
# X5123XAL
# X5850XAA
# X5870XAB
# X2594XAC
# Buscar CPA
# X5143XAC
# X5155XAL
# X5220XAT
# X2550XAB
# X5284XBB
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5244XAN
# Buscar CPA
# X5125XAA
# X5885XAB
# X5209XAY
# X5186XAA
# X5119XAG
# Buscar CPA
# X5155XAL
# X5131XAW
# X6225XAA
# Error al acceder a la página de caã±a-cruz: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-ancha-santa-rosa: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-alvarez: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-coria: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-cuevas: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-jume: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-las-chacras: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-las-gatiadas: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-luque: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-machado: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-machado-sud: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-mateo: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-mayo: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-pocho: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-rio-pinto: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-de-salas: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-del-durazno: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-del-puerto: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-del-sauce: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-del-simbol: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-del-tala: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-grande: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-honda: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-larga: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-san-antonio: Exceeded 10 redirects.
# Error al acceder a la página de caã±ada-verde: Exceeded 10 redirects.
# Error al acceder a la página de caã±adas-hondas: Exceeded 10 redirects.
# Error al acceder a la página de caã±adon-de-los-mogotes: Exceeded 10 redirects.
# X5155XAL
# Buscar CPA
# Buscar CPA
# X5221XAT
# X5209XAY
# X5284XBB
# Buscar CPA
# X5282XAL
# X5201XAU
# Buscar CPA
# Buscar CPA
# X5151XAH
# X5191XAC
# X5205XAA
# X5244XAN
# X5101XAB
# X5231XAA
# X5149XAB
# Buscar CPA
# X5915XAA
# X5943XAA
# X2421XAG
# X2426XAB
# X5149XAB
# X2423XAE
# X5139XAG
# X5801XAJ
# X5236XAA
# X2555XAB
# X5231XAA
# X5221XAT
# X5987XAD
# X5287XAD
# Buscar CPA
# X5151XAH
# X5101XAB
# X5101XAB
# X5873XAC
# Buscar CPA
# Buscar CPA
# X5129XAJ
# X2415XAB
# X5196XAE
# X5925XAC
# Buscar CPA
# X5151XAH
# X5155XAL
# X2671XAD
# X5178XAA
# X5209XAY
# X5131XAW
# X5901XAD
# X5191XAC
# Error al acceder a la página de chaã±ar-viejo: Exceeded 10 redirects.
# Error al acceder a la página de chaã±ariaco: Exceeded 10 redirects.
# Error al acceder a la página de chaã±aritos: Exceeded 10 redirects.
# X5282XAL
# X5284XBB
# X5284XBB
# X5244XAN
# X5242XAA
# Buscar CPA
# Buscar CPA
# X5299XAN
# X5871XAD
# X5870XAB
# X5287XAD
# X5282XAL
# X5127XAD
# Buscar CPA
# Buscar CPA
# X2671XAD
# Buscar CPA
# X2671XAD
# X5244XAN
# X5871XAD
# Error al acceder a la página de chuã±a: Exceeded 10 redirects.
# Error al acceder a la página de chuã±a-huasi: Exceeded 10 redirects.
# X5875XAC
# Buscar CPA
# Error al acceder a la página de churqui-caã±ada: Exceeded 10 redirects.
# Buscar CPA
# X5297XAO
# X5289XAA
# X2559XAB
# X5119XAG
# X5857XAD
# Buscar CPA
# X2349XAD
# X2581XAA
# X5196XAE
# X5987XAD
# X5941XAA
# X2413XAD
# X2436XAC
# Buscar CPA
# X5155XAL
# X2659XAA
# X2421XAG
# X6270XAC
# Buscar CPA
# Error al acceder a la página de colonia-caã±adon: Exceeded 10 redirects.
# X2580XAA
# X5223XAA
# X2415XAB
# X2436XAC
# X2435XAB
# X2424XAB
# X5847XAB
# X2428XAA
# X5809XAA
# X6270XAC
# X2421XAG
# X5801XAJ
# X2594XAC
# Buscar CPA
# X2424XAB
# X2424XAB
# X2413XAD
# X5987XAD
# X5945XAA
# X2415XAB
# X5933XAA
# Buscar CPA
# Buscar CPA
# X2413XAD
# X5196XAE
# X6141XAA
# X5847XAB
# X2559XAB
# Buscar CPA
# X6132XAB
# X2423XAE
# X2580XAA
# Buscar CPA
# X5801XAJ
# X5933XAA
# X6120XAD
# X2435XAB
# Buscar CPA
# X5131XAW
# X2433XAF
# X2415XAB
# Buscar CPA
# X2189XAA
# X5850XAA
# X2684XAA
# X2424XAB
# X2559XAB
# X2349XAD
# X2349XAD
# X5875XAC
# X2415XAB
# X5841XAC
# X2415XAB
# X5801XAJ
# X2413XAD
# Buscar CPA
# X2423XAE
# X2426XAB
# Buscar CPA
# X2421XAG
# X2433XAF
# X6123XAE
# X5851XAD
# X5933XAA
# X2423XAE
# Buscar CPA
# X5121XAB
# X2421XAG
# X5101XAB
# X5139XAG
# Buscar CPA
# X6121XAA
# X2413XAD
# X2592XAA
# X5221XAT
# Buscar CPA
# X5137XAV
# Buscar CPA
# X2436XAC
# X5220XAT
# X5875XAC
# X5871XAD
# X5871XAD
# X5873XAC
# X5125XAA
# X5201XAU
# X5153XAG
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5847XAB
# X5221XAT
# Buscar CPA
# X5870XAB
# X5940XAA
# X5945XAA
# X5913XAF
# X5295XAF
# X2671XAD
# X5879XAA
# X2661XAA
# Buscar CPA
# Buscar CPA
# Error al acceder a la página de costa-del-castaã±o: Exceeded 10 redirects.
# X6271XAC
# X5801XAJ
# X5961XAB
# Buscar CPA
# X2424XAB
# X2189XAA
# X5178XAA
# Error al acceder a la página de cruz-de-caã±a: Exceeded 10 redirects.
# Buscar CPA
# X5221XAT
# X5212XAO
# X2550XAC
# X5801XAJ
# X5155XAL
# X5295XAA
# X6120XAE
# X6271XAC
# Buscar CPA
# X6271XAC
# X2684XAA
# X5284XBB
# Error al acceder a la página de despeã±aderos: Exceeded 10 redirects.
# Buscar CPA
# X5299XAN
# Buscar CPA
# X2424XAB
# X5131XAW
# X5875XAC
# Buscar CPA
# Error al acceder a la página de dique-la-viã±a: Exceeded 10 redirects.
# X5168XAB
# X5149XAB
# Error al acceder a la página de doctor-nicasio-salas-oroã±o: Exceeded 10 redirects.
# Error al acceder a la página de dolores-nuã±ez-del-prado: Exceeded 10 redirects.
# X5182XAD
# X5164XAA
# Buscar CPA
# Buscar CPA
# X2349XAD
# X5119XAG
# X5149XAB
# X5244XAN
# Buscar CPA
# Buscar CPA
# X5885XAB
# X5295XAF
# X5221XAT
# X5248XAB
# Error al acceder a la página de el-araã±ado: Exceeded 10 redirects.
# Error al acceder a la página de el-baã±ado: Exceeded 10 redirects.
# X5137XAV
# X5889XAG
# X5285XAD
# X5871XAD
# Buscar CPA
# X5281XAY
# X5172XAB
# X5821XAF
# X5284XBB
# Error al acceder a la página de el-carmen-guiã±azu: Exceeded 10 redirects.
# Buscar CPA
# Error al acceder a la página de el-carrizal-chuã±ahuasi: Exceeded 10 redirects.
# X5236XAA
# X5205XAA
# Buscar CPA
# Buscar CPA
# X5951XAB
# X5282XAL
# X5248XAB
# X5248XAB
# X5248XAB
# X5248XAB
# Buscar CPA
# X2580XAA
# Error al acceder a la página de el-parador-de-la-montaã±a: Exceeded 10 redirects.
# X5871XAD
# X5151XAH
# X5151XAH
# X5236XAA
# X5201XAU
# X5155XAL
# X5155XAL
# X5178XAA
# Error al acceder a la página de el-porteã±o: Exceeded 10 redirects.
# X5196XAE
# Buscar CPA
# Buscar CPA
# X5801XAJ
# X5233XAA
# X5248XAB
# X5295XAF
# X5172XAB
# Buscar CPA
# X5101XAB
# Buscar CPA
# X5270XAI
# Buscar CPA
# X6121XAA
# X5220XAT
# X5285XAD
# X5201XAU
# X5205XAA
# X5282XAL
# Buscar CPA
# X5887XAA
# X5244XAN
# X5248XAB
# X5281XAY
# X5201XAU
# X5248XAB
# X5212XAO
# X5212XAO
# X5801XAJ
# X2432XAE
# X5149XAB
# X5864XAA
# X5137XAV
# X2424XAB
# Buscar CPA
# X5295XAF
# X5216XAE
# X5182XAD
# X5172XAB
# Buscar CPA
# Buscar CPA
# X5231XAA
# X5155XAL
# X5233XAA
# X5149XAB
# X5233XAA
# Buscar CPA
# Buscar CPA
# X5231XAA
# X2587XAA
# X5282XAL
# X5101XAB
# Buscar CPA
# Error al acceder a la página de espinillo-nuã±ez-del-prado: Exceeded 10 redirects.
# Buscar CPA
# X5281XAY
# X5145XAK
# D5757XAC
# X2550XAB
# Buscar CPA
# X5220XAT
# Buscar CPA
# X5843XAA
# X5284XBB
# Buscar CPA
# Buscar CPA
# X5155XAL
# Buscar CPA
# Error al acceder a la página de estancia-el-chaã±ar: Exceeded 10 redirects.
# X5244XAN
# Buscar CPA
# X5212XAO
# X2428XAA
# X2428XAA
# X5186XAA
# Error al acceder a la página de estancia-las-caã±as: Exceeded 10 redirects.
# X2671XAC
# Buscar CPA
# Buscar CPA
# X5987XAD
# Error al acceder a la página de estancia-patiã±o: Exceeded 10 redirects.
# X5152XAD
# X5248XAB
# X5850XAA
# Buscar CPA
# X5186XAA
# X5925XAC
# X2525XAA
# X5847XAB
# X6120XAE
# X2413XAD
# X5967XAB
# X6132XAB
# X5809XAA
# X5933XAA
# X5101XAB
# X6132XAB
# X5151XAH
# X6140XAB
# X2592XAA
# X6142XAA
# X2671XAC
# Buscar CPA
# X5186XAA
# X5209XAY
# X5172XAB
# X5244XAN
# X5875XAC
# X5281XAY
# X6120XAE
# X5285XAD
# X5155XAL
# Buscar CPA
# X5821XAF
# X5295XAF
# X5236XAA
# X5123XAL
# Buscar CPA
# X5125XAA
# X6225XAA
# X5825XAA
# X5885XAB
# X6121XAA
# X6121XAA
# Buscar CPA
# X5875XAC
# X5887XAA
# X5174XAB
# X6270XAC
# X5270XAI
# X5987XAD
# X5988XAB
# Buscar CPA
# Buscar CPA
# X2587XAA
# X5209XAY
# X5168XAB
# X5201XAU
# Buscar CPA
# X5129XAJ
# X5129XAJ
# X2559XAB
# X6271XAC
# X5203XAB
# Buscar CPA
# X5209XAY
# X2424XAB
# Buscar CPA
# X5220XAT
# Buscar CPA
# X6127XAC
# Buscar CPA
# X5212XAO
# X5145XAK
# X6120XAD
# X5209XAY
# Buscar CPA
# X5248XAB
# X5123XAL
# X5901XAD
# X5139XAG
# X5137XAV
# X5137XAV
# Buscar CPA
# X5238XAB
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X2424XAB
# X5284XBB
# X6142XAA
# X6121XAA
# X5168XAB
# X2428XAA
# Buscar CPA
# X5149XAB
# X5125XAA
# X5123XAL
# X5123XAL
# X5125XAA
# X5123XAL
# X5125XAA
# X5145XAK
# X5220XAT
# X5212XAO
# X5212XAO
# X5212XAO
# Buscar CPA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5216XAE
# X5216XAE
# X5281XAY
# X5293XAA
# Buscar CPA
# X5295XAF
# X5875XAC
# X5201XAU
# X5270XAI
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5848XAB
# X5129XAJ
# Error al acceder a la página de la-caã±ada: Exceeded 10 redirects.
# Error al acceder a la página de la-caã±ada-angosta: Exceeded 10 redirects.
# Error al acceder a la página de la-caã±ada-grande: Exceeded 10 redirects.
# Error al acceder a la página de la-caã±ada-santa-cruz: Exceeded 10 redirects.
# X2563XAC
# X5168XAB
# Buscar CPA
# X5841XAC
# Buscar CPA
# X6142XAA
# X5125XAA
# Buscar CPA
# X5212XAO
# X5295XAF
# X5196XAE
# Buscar CPA
# X5201XAU
# D5757XAC
# X5871XAD
# X5220XAT
# X5194XAD
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5212XAO
# Buscar CPA
# X5129XAJ
# X5172XAB
# X2426XAB
# X5282XAL
# X2433XAF
# X5879XAA
# X5848XAB
# X5282XAL
# X5186XAA
# X5115XAB
# X5889XAG
# Buscar CPA
# X5900XAE
# X5285XAD
# X5801XAJ
# Buscar CPA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5871XAD
# X5281XAY
# X6271XAC
# X5231XAA
# X5841XAC
# X5285XAD
# X2400XAA
# X5137XAV
# X5299XAN
# Buscar CPA
# G5255XBJ
# Buscar CPA
# X5925XAC
# X5231XAA
# X5913XAF
# X5117XAA
# Buscar CPA
# X5137XAV
# X5871XAD
# X6271XAC
# X2671XAD
# Buscar CPA
# X5285XAD
# X5244XAN
# X5875XAC
# X5945XAA
# X5119XAG
# Error al acceder a la página de la-porteã±a: Exceeded 10 redirects.
# Buscar CPA
# Error al acceder a la página de la-posta-chuã±aguas: Exceeded 10 redirects.
# X5139XAG
# X5231XAA
# X5284XBB
# X5295XAF
# Buscar CPA
# X5105XAA
# X5925XAC
# X2436XAC
# X5233XAA
# X5295XAF
# X5951XAB
# Buscar CPA
# X5212XAO
# Buscar CPA
# X5875XAC
# X5295XAF
# X5299XAN
# Buscar CPA
# X5209XAY
# X5871XAD
# X5875XAC
# Buscar CPA
# X5212XAO
# Buscar CPA
# X2413XAD
# X5168XAB
# X5870XAB
# X5801XAJ
# Buscar CPA
# X5231XAA
# X5201XAU
# X5913XAF
# X5913XAF
# X6120XAE
# X5244XAN
# Buscar CPA
# X6144XAA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5270XAI
# X5231XAA
# Error al acceder a la página de las-caã±adas: Exceeded 10 redirects.
# Error al acceder a la página de las-caã±as: Exceeded 10 redirects.
# Error al acceder a la página de las-caã±itas: Exceeded 10 redirects.
# X5801XAJ
# X5885XAB
# X5841XAC
# X5885XAB
# X5201XAU
# Buscar CPA
# X5801XAJ
# X5101XAB
# Buscar CPA
# Buscar CPA
# X5137XAV
# X5244XAN
# X5931XAB
# X5203XAB
# Buscar CPA
# X5272XAB
# X5284XBB
# X5212XAO
# X5231XAA
# X5295XAF
# Buscar CPA
# Buscar CPA
# X5801XAJ
# X5871XAD
# X2559XAB
# X2559XAB
# X5870XAB
# X5201XAU
# X5182XAD
# Error al acceder a la página de las-peã±as: Exceeded 10 redirects.
# Error al acceder a la página de las-peã±as-norte: Exceeded 10 redirects.
# Error al acceder a la página de las-peã±as-sud: Exceeded 10 redirects.
# Buscar CPA
# X5900XAE
# X5212XAO
# X5281XAY
# X5129XAJ
# X5101XAB
# X5244XAN
# X5885XAB
# X5295XAA
# X5212XAO
# X5199XAK
# X5285XAD
# X2671XAD
# X5879XAA
# Buscar CPA
# Buscar CPA
# X5941XAA
# X5940XAA
# X5843XAA
# X5248XAB
# Buscar CPA
# X6273XAB
# X6128XAA
# X2594XAC
# X2671XAD
# X5201XAU
# X5209XAY
# X5879XAA
# X5244XAN
# X5299XAN
# X5137XAV
# X5244XAN
# Buscar CPA
# Buscar CPA
# X5137XAV
# Buscar CPA
# X5209XAY
# X5201XAU
# Buscar CPA
# X2671XAD
# Error al acceder a la página de los-castaã±os: Exceeded 10 redirects.
# X5101XAB
# X5201XAU
# X5137XAV
# X5821XAF
# Error al acceder a la página de los-chaã±ares: Exceeded 10 redirects.
# Error al acceder a la página de los-chaã±aritos: Exceeded 10 redirects.
# X5248XAB
# X2684XAA
# X5221XAT
# Buscar CPA
# X5201XAU
# X2421XAG
# X5871XAD
# X5220XAT
# X5220XAT
# X5270XAI
# X6127XAC
# X5155XAL
# X5282XAL
# X5127XAD
# X5168XAB
# X5281XAY
# X5885XAB
# X5295XAF
# X5153XAG
# X5843XAA
# X5295XAF
# X5873XAC
# X5127XAD
# X5871XAD
# Buscar CPA
# X5137XAV
# X5221XAT
# X5182XAD
# Buscar CPA
# Buscar CPA
# X5101XAB
# X5284XBB
# X5125XAA
# X5186XAA
# X5282XAL
# X5212XAO
# X5201XAU
# X5850XAA
# Buscar CPA
# Buscar CPA
# X5221XAT
# X2671XAD
# X5194XAD
# X5925XAC
# X5201XAU
# X5282XAL
# Buscar CPA
# X2581XAA
# X5233XAA
# X5299XAN
# Buscar CPA
# X2559XAB
# Buscar CPA
# X5851XAD
# X2671XAD
# X2559XAB
# X5270XAI
# X5125XAA
# X5901XAD
# X5101XAB
# Buscar CPA
# X2423XAE
# X5967XAB
# X5859XAG
# X5936XAB
# X5875XAC
# X5212XAY
# X5287XAD
# Error al acceder a la página de malagueã±o: Exceeded 10 redirects.
# X5843XAA
# X5155XAL
# X5125XAA
# X5284XBB
# X5988XAB
# Buscar CPA
# X5199XAK
# X2580XAA
# X5925XAC
# X5139XAG
# X2659XAA
# Buscar CPA
# X6271XAC
# X2421XAG
# X5153XAG
# X5125XAA
# X5281XAY
# X6270XAC
# X6123XAE
# X5248XAB
# X5285XAD
# X5153XAG
# X5125XAA
# X5101XAB
# X5225XAB
# X5297XAO
# X5889XAG
# Buscar CPA
# X5221XAT
# X5143XAC
# X6273XAB
# Error al acceder a la página de modesto-acuã±a: Exceeded 10 redirects.
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5212XAO
# X5851XAD
# X2563XAC
# X5125XAA
# D5757XAC
# X5900XAE
# X5131XAW
# X5931XAB
# X5129XAJ
# Buscar CPA
# X5119XAG
# X5801XAJ
# Error al acceder a la página de monte-leã±a: Exceeded 10 redirects.
# X2659XAA
# X5119XAG
# X2568XAA
# X2421XAG
# X5221XAT
# X5299XAN
# X5209XAY
# X6270XAC
# Buscar CPA
# Error al acceder a la página de niã±a-paula: Exceeded 10 redirects.
# X5870XAB
# X6271XAC
# X5889XAG
# Buscar CPA
# X5220XAT
# X2563XAC
# X5887XAA
# Error al acceder a la página de nuã±ez-del-prado: Exceeded 10 redirects.
# X5101XAB
# Buscar CPA
# X5225XAB
# Buscar CPA
# X5293XAA
# Buscar CPA
# Buscar CPA
# X2684XAA
# Buscar CPA
# X5125XAA
# Buscar CPA
# Error al acceder a la página de ordoã±ez: Exceeded 10 redirects.
# X5951XAB
# X5893XAC
# X6121XAA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5281XAY
# X5961XAB
# X5281XAY
# X5284XBB
# X5284XBB
# X5153XAG
# Buscar CPA
# X5931XAB
# X5931XAB
# X5893XAC
# Buscar CPA
# X5925XAC
# Buscar CPA
# X5145XAK
# X2433XAF
# X5284XBB
# X5101XBE
# Buscar CPA
# X5101XAB
# X2671XAD
# Buscar CPA
# X5887XAA
# X5819XAG
# X5284XBB
# Buscar CPA
# D5738XAV
# X6121XAA
# X5233XAA
# X2671XAC
# X5127XAD
# X5284XBB
# X5168XAB
# X5174XAB
# X5284XBB
# X5174XAB
# X5172XAB
# X5271XAA
# X5295XAA
# X5101XBE
# Buscar CPA
# X6271XAC
# X5125XAA
# X5244XAN
# X5295XAA
# X5139XAG
# X2436XAC
# X5137XAV
# X5967XAB
# X5987XAD
# Buscar CPA
# Buscar CPA
# X5299XAN
# X5248XAB
# Error al acceder a la página de porteã±a: Exceeded 10 redirects.
# Buscar CPA
# Buscar CPA
# X5191XAC
# X5297XAO
# Buscar CPA
# X5221XAT
# X5221XAT
# Buscar CPA
# X5125XAA
# X5871XAD
# X5137XAV
# Error al acceder a la página de pozo-del-chaã±ar: Exceeded 10 redirects.
# X2433XAF
# X5225XAB
# X6140XAB
# X5800XAA
# Buscar CPA
# Buscar CPA
# X5281XAY
# X5284XBB
# X5299XAN
# X2423XAE
# X5871XAD
# X5885XAB
# Buscar CPA
# X5270XAI
# X5221XAT
# X5295XAF
# X5119XAG
# X5225XAB
# X5284XBB
# X5289XAA
# X5900XAE
# Buscar CPA
# X6271XAC
# X5287XAD
# X2671XAD
# Buscar CPA
# X5285XAD
# X5961XAB
# X5162XAA
# X5197XAA
# X5887XAA
# X6120XAD
# Buscar CPA
# X5221XAT
# X5800XAA
# X5875XAC
# Buscar CPA
# X5221XAT
# X5197XAA
# X5295XAF
# X5172XAB
# X5199XAK
# X2671XAD
# X5221XAT
# X5127XAD
# X5295XAF
# Buscar CPA
# X5850XAA
# X5209XAY
# X5821XAF
# X5875XAC
# X5821XAF
# X5801XAJ
# X2671XAD
# X6128XAA
# X6120XAE
# X5289XAA
# X5285XAD
# X5101XAB
# X5125XAA
# X5945XAA
# X2525XAA
# Buscar CPA
# X2587XAA
# X5149XAB
# X6120XAE
# X5295XAA
# X5873XAC
# Buscar CPA
# X5191XAC
# X5848XAB
# X5153XAG
# X5236XAA
# X2559XAB
# X5936XAA
# X5119XAG
# X5295XAF
# X5801XAJ
# X5841XAC
# X5164XAA
# X5186XAA
# X5248XAB
# X5182XAD
# Buscar CPA
# X2400XAA
# Error al acceder a la página de san-francisco-del-chaã±ar: Exceeded 10 redirects.
# X5244XAN
# X5297XAO
# X5875XAC
# X6123XAE
# X5117XAA
# X5244XAN
# X5216XAE
# Error al acceder a la página de san-jose-del-salteã±o: Exceeded 10 redirects.
# X5295XAF
# Buscar CPA
# X5209XAY
# X5282XAL
# X5295XAF
# Buscar CPA
# X5871XAD
# X5871XAD
# X5201XAU
# X5205XAA
# X5221XAT
# X5889XAG
# X5901XAD
# Buscar CPA
# X6123XAE
# X6120XAD
# X5201XAU
# X2671XAC
# Buscar CPA
# X6127XAC
# X5164XAA
# X5197XAA
# X5196XAE
# Buscar CPA
# X5174XAB
# X5221XAT
# X5221XAT
# Buscar CPA
# X5248XAB
# X5125XAA
# X5220XAT
# Buscar CPA
# X5196XAE
# X5925XAC
# X5212XAO
# X5943XAA
# Buscar CPA
# X5297XAO
# Buscar CPA
# X5231XAA
# Buscar CPA
# X5857XAD
# X5284XBB
# X5270XAI
# X5205XAA
# X5819XAG
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5220XAT
# X5191XAC
# X5209XAY
# Buscar CPA
# X5153XAG
# X5137XAV
# Buscar CPA
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5870XAB
# X5281XAY
# X5295XAF
# X6123XAE
# X5233XAA
# Error al acceder a la página de tala-caã±ada: Exceeded 10 redirects.
# X5859XAG
# X5284XBB
# X5153XAG
# Buscar CPA
# X5127XAD
# Buscar CPA
# X5933XAA
# X5155XAL
# X5155XAL
# X5155XAL
# X5299XAN
# X5284XBB
# X5893XAC
# Buscar CPA
# X5125XAA
# X5101XAB
# Buscar CPA
# X5859XAG
# X5873XAC
# X5129XAJ
# Buscar CPA
# Buscar CPA
# X5936XAA
# X5201XAU
# X5123XAL
# X6271XAC
# X5139XAG
# X5289XAA
# X6141XAA
# X5284XBB
# Buscar CPA
# X5216XAE
# Buscar CPA
# X5201XAU
# X2436XAC
# X5285XAD
# Error al acceder a la página de tres-chaã±ares: Exceeded 10 redirects.
# Buscar CPA
# Buscar CPA
# X5101XBE
# Buscar CPA
# X5149XAB
# X5223XAA
# X5284XBB
# X5203XAB
# X5216XAE
# X5857XAD
# Buscar CPA
# Buscar CPA
# X5859XAG
# X5143XAC
# X5248XAB
# X5864XAA
# X5168XAB
# X5115XAB
# X2671XAD
# X2671XAC
# Error al acceder a la página de vicuã±a-mackenna: Exceeded 10 redirects.
# X5857XAD
# Buscar CPA
# X5221XAT
# X5105XAA
# X5194XAD
# X5199XAK
# X5885XAB
# Buscar CPA
# X5900XAE
# X5194XAD
# X5164XAA
# X5164XAA
# X5295XAF
# X5152XAD
# Buscar CPA
# X5248XAB
# X5221XAT
# Buscar CPA
# Buscar CPA
# X5885XAB
# X5201XAU
# X2433XAF
# X5101XAB
# X5153XAG
# X5153XAG
# Buscar CPA
# X5885XAB
# X5248XAB
# X5284XBB
# X5152XAD
# Buscar CPA
# Buscar CPA
# X5859XAG
# X5236XAA
# Buscar CPA
# X5870XAB
# X5801XAJ
# X5199XAK
# Buscar CPA
# X5199XAK
# X2594XAC
# X5900XAE
# X5101XAB
# X5155XAL
# X5137XAV
# X5194XAD
# X5236XAA
# X5153XAG
# X5212XAO
# Buscar CPA
# X5153XAG
# Buscar CPA
# X5819XAG
# Buscar CPA
# X5199XAK
# X5248XAB
# Buscar CPA
# Buscar CPA
# Buscar CPA
# X5281XAY
# X2550XAC
# X5137XAV
# X5123XAL
# Buscar CPA
# X5864XAA
# X5903XAA
# X5101XAB
# X5152XAD
# X5123XAL
# Buscar CPA
# X5859XAG
# X5885XAB
# X5153XAG
# X5233XAA
# X6128XAA
# X5864XAA
# Buscar CPA
# X5199XAK
# Buscar CPA
# X5152XAD
# Buscar CPA
# X5801XAJ
# Buscar CPA
# Buscar CPA
# X5857XAD
# X5295XAA
# Buscar CPA
# X6273XAB
# X2435XAB
# X2426XAB
# X5197XAA
# X5295XAA
# X5197XAA
# X6128XAA
# X6144XAA
# X6270XAC
# X5248XAB
# X5841XAC
# X5153XAG
# Buscar CPA
# X5101XAB
# X5873XAC
# X5843XAA
# Archivo CSV guardado exitosamente.
